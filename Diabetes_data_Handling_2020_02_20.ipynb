# %% [markdown]
# <a href="https://colab.research.google.com/github/seungbok3240/DeepLearning/blob/master/Diabetes_data_Handling_2020_02_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # 사이킷런에서 당뇨병 환자 데이터 가져오기

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()

# %% [markdown]
# # 입력 데이터크기

# %%
diabetes.data.shape
# Out:
# (442, 10)

# %% [markdown]
# # 타깃 데이터 크기

# %%
diabetes.target.shape
# Out:
# (442,)

# %% [markdown]
# 입력데이터 : 442x10 크기의 2차원배열
# <br>
# 타깃데이터 : 442개의 요소를 가진 1차원배열
# <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 데이터 살펴보기

# %% [markdown]
# 입력 데이터 살펴보기

# %%
diabetes.data[0:3]
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621,  0.02187235, -0.0442235 ,
#         -0.03482076, -0.04340085, -0.00259226,  0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, -0.02632783, -0.00844872,
#         -0.01916334,  0.07441156, -0.03949338, -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, -0.00567061, -0.04559945,
#         -0.03419447, -0.03235593, -0.00259226,  0.00286377, -0.02593034]])

# %% [markdown]
# 타깃 데이터 살펴보기

# %%
diabetes.target[:3]
# Out:
# array([151.,  75., 141.])

# %% [markdown]
# # 데이터 시각화하기

# %%
import matplotlib.pyplot as plt
plt.scatter(diabetes.data[:,2],diabetes.target) #한가지 특성만 가지고 산점도 그래프를 그린다.(10가지 특성은 고차원 그래프가 필요)
plt.xlabel('x') #X축 이름
plt.ylabel('y') #Y축 이름
plt.show()

# %% [markdown]
# # 훈련 데이터 준비하기

# %%
x = diabetes.data[:,2]
y = diabetes.target
